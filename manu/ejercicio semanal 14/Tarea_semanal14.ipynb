# %% [markdown]
# ## Tarea semanal 14
#
# ## Alumno: Manuel Dieguez (R4052)

# %%
from IPython.display import IFrame, display
IFrame("./tarea_semanal_14.pdf",700,700)
# Out:
#         <iframe
#             width="700"
#             height="700"
#             src="./tarea_semanal_14.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Luego procedemos a realizar las verificaciones circuitales con LTSpice, verificando que todas cumplen con la atenuacion requerida.

# %% [markdown]
# ![Punto1.png](attachment:Punto1.png)

# %% [markdown]
# ![Punto2a.png](attachment:Punto2a.png)

# %% [markdown]
# ![PUNto2d.png](attachment:PUNto2d.png)
