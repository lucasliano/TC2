# %% [markdown]
# ## Ejercicio semanal 13
# ## Alumno: Manuel Dieguez (R4052)

# %%
from IPython.display import IFrame, display
IFrame("./ejercicio_sem13.pdf",700,700)
# Out:
#         <iframe
#             width="700"
#             height="700"
#             src="./ejercicio_sem13.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Simulaciones del punto 1

# %%
import numpy as np 
import matplotlib.pyplot as plt
from splane import pzmap, bodePlot
from scipy import signal

# %%
#Simulacion del punto 1
tf = signal.TransferFunction([1,5,4],[1,8,12]) ##Y11
w=np.logspace(-1,2,1000,True,10.0,None,0) #Donde voy evaluar mi funcion de transferencia para el bode
#Armo el Bode
w, mag, fase = signal.bode(tf,w,None);

#Muestro mi diagrama de Bode
plt.figure()
plt.grid()
plt.semilogx(w, mag)    # Bode magnitud

##plt.ylim([-15 , 15])    #Limites del grafico de magnitud eje y (magnitud)
plt.figure()
plt.grid()
plt.semilogx(w, fase)  # Bode 
plt.show()

pzmap(tf)
# Out:
# (1, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %% [markdown]
# ![circ1.png](attachment:circ1.png)

# %% [markdown]
# ![sim1.png](attachment:sim1.png)

# %% [markdown]
# ## Simulaciones del punto 2

# %%
#Simulacion del punto 1
tf = signal.TransferFunction([1,0,9],[1,2,2,1]) ##Y11
w=np.logspace(-1,2,1000,True,10.0,None,0) #Donde voy evaluar mi funcion de transferencia para el bode
#Armo el Bode
w, mag, fase = signal.bode(tf,w,None);

#Muestro mi diagrama de Bode
plt.figure()
plt.grid()
plt.semilogx(w, mag)    # Bode magnitud

##plt.ylim([-15 , 15])    #Limites del grafico de magnitud eje y (magnitud)
plt.figure()
plt.grid()
plt.semilogx(w, fase)  # Bode 
plt.show()

pzmap(tf)
# Out:
# (1, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %% [markdown]
# ![circ2.png](attachment:circ2.png)

# %% [markdown]
# ![sim2.png](attachment:sim2.png)
